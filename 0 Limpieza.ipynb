# %% [markdown]
# <h1 style="text-align:center;"><b>Data Science - Proyecto 1: Limpieza de Datos</b></h1>
# <h3 style="text-align:center;">Alina Carías, Marcos Díaz, Ariela Mishaan </h3>

# %%
import os
import glob
import pandas as pd 
import re

# %%
#import sys
#!{sys.executable} -m pip install --user "thefuzz"

# %% [markdown]
# # Enlace al Repositorio

# %% [markdown]
# https://github.com/ArielaMishaanCohen/2-Proyecto-1.git

# %% [markdown]
# # 1. Carga de datos
#
# En este paso, no solamente se importaron los CSVs desde el fólder en el directorio, sino también se aprovechó el ciclo for para eliminar las filas y columnas vacías o inútiles que traían los exceles. Dado que todos venían en exactamente el mismo formato, se pudo inspeccionar exactamente qué era lo que se necesitaba, para hacer el proceso de forma masiva. El proceso es el siguiente:
#
# 1. Carga de archivo csv en un dataframe de pandas.
# 2. Leer solamente las filas donde hay datos relevantes (de la 27 hasta antes de las últimas 5)
# 3. Cambiar el encabezado, poner en él los nombres de las columnas.
# 4. Borrar las columnas con solo datos inexistentes (NA - estas son por el formato en el que venían los archivos)
# 5. Resetear los índices del dataframe de pandas para que sean manejables los datos.
# 6. Agregar el dataframe del departamento a la lista con todos los dataframes.

# %%
folder_path = "Datos/CSVs" 
contenido = os.listdir(folder_path)
csv_files = glob.glob(f'{folder_path}/*.csv')

datos = []

for file_path in csv_files:
    print(f"Leyendo archivo: {file_path}")

    # Leer el df, borrando las primeras 27 filas de todos los archivos y las últimas 7
    df = pd.read_csv(file_path, header = None )[25:-5]

    # Cambiar el header para poner los nombres de las columnas
    new_header = df.iloc[0]  
    df2 = df[1:].copy()     
    df2.columns = new_header   

    # Borrar la segunda columna y las últimas dos
    indices = [1, -1,-2]
    df_dropped_multiple = df2.drop(df2.columns[indices], axis=1)

    # Resetear los índices
    df2 = df2.reset_index(drop = True)

    #Meter el dataframe a la lista
    datos.append(df2)

df_unido = pd.concat(datos, ignore_index=True)

print("\nImportación realizada con éxito")
# Out:
# Leyendo archivo: Datos/CSVs/Quiché.csv
# Leyendo archivo: Datos/CSVs/Totonicapán.csv
# Leyendo archivo: Datos/CSVs/Suchitepéquez.csv
# Leyendo archivo: Datos/CSVs/Sololá.csv
# Leyendo archivo: Datos/CSVs/Sacatepéquez.csv
# Leyendo archivo: Datos/CSVs/San Marcos.csv
# Leyendo archivo: Datos/CSVs/Ciudad Capital.csv
# Leyendo archivo: Datos/CSVs/Chiquimula.csv
# Leyendo archivo: Datos/CSVs/Santa Rosa.csv
# Leyendo archivo: Datos/CSVs/Izabal.csv
# Leyendo archivo: Datos/CSVs/Petén.csv
# Leyendo archivo: Datos/CSVs/Retalhuleu.csv
# Leyendo archivo: Datos/CSVs/Alta Verapaz.csv
# Leyendo archivo: Datos/CSVs/Baja Verapaz.csv
# Leyendo archivo: Datos/CSVs/Zacapa.csv
# Leyendo archivo: Datos/CSVs/Chimaltenango.csv
# Leyendo archivo: Datos/CSVs/Quetzaltenango.csv
# Leyendo archivo: Datos/CSVs/Guatemala.csv
# Leyendo archivo: Datos/CSVs/Escuintla.csv
# Leyendo archivo: Datos/CSVs/Huehuetenango.csv
# Leyendo archivo: Datos/CSVs/Jalapa.csv
# Leyendo archivo: Datos/CSVs/El Progreso.csv
# Leyendo archivo: Datos/CSVs/Jutiapa.csv
#
# Importación realizada con éxito

# %% [markdown]
# Se importaron todos los datos. Como tiene todas las mismas columnas, se unen horizontalmente para integrarlo todo en un mismo dataframe y manejarlo como un conjunto de datos.

# %% [markdown]
# # 2. Análisis del estado de los datos crudos

# %%
# Muestra la información del dataset unido
print(df_unido.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6600 entries, 0 to 6599
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CODIGO           6600 non-null   object
#  1   DISTRITO         6600 non-null   object
#  2   DEPARTAMENTO     6600 non-null   object
#  3   MUNICIPIO        6600 non-null   object
#  4   ESTABLECIMIENTO  6600 non-null   object
#  5   DIRECCION        6598 non-null   object
#  6   TELEFONO         6554 non-null   object
#  7   SUPERVISOR       6600 non-null   object
#  8   DIRECTOR         6574 non-null   object
#  9   NIVEL            6600 non-null   object
#  10  SECTOR           6600 non-null   object
#  11  AREA             6600 non-null   object
#  12  STATUS           6600 non-null   object
#  13  MODALIDAD        6600 non-null   object
#  14  JORNADA          6600 non-null   object
#  15  PLAN             6600 non-null   object
#  16  DEPARTAMENTAL    6600 non-null   object
# dtypes: object(17)
# memory usage: 876.7+ KB
# None

# %% [markdown]
# SE puede ver que hay 16 columnas, cada una con 6600 objetos no nulos. Esto quiere decir que en ninguna columna tenemos datos faltantes.

# %%
# Revisa valores únicos por columna
for col in df_unido.columns:
    print(f"\nColumna: {col}")
    print(df_unido[col].value_counts(dropna=False).head())

# Revisa valores nulos
print()
print(df_unido.isnull().sum())
# Out:
# Columna: CODIGO
# CODIGO
# 14-01-0077-46    1
# 01-03-0097-46    1
# 01-03-0129-46    1
# 01-03-0128-46    1
# 01-03-0127-46    1
# Name: count, dtype: int64
#
# Columna: DISTRITO
# DISTRITO
# 01-403    160
# 11-017    139
# 01-411    103
# 05-033     94
# 18-039     84
# Name: count, dtype: int64
#
# Columna: DEPARTAMENTO
# DEPARTAMENTO
# GUATEMALA         1038
# CIUDAD CAPITAL     867
# SAN MARCOS         432
# ESCUINTLA          393
# QUETZALTENANGO     365
# Name: count, dtype: int64
#
# Columna: MUNICIPIO
# MUNICIPIO
# ZONA 1            303
# MIXCO             300
# VILLA NUEVA       223
# QUETZALTENANGO    175
# RETALHULEU        156
# Name: count, dtype: int64
#
# Columna: ESTABLECIMIENTO
# ESTABLECIMIENTO
# INSTITUTO NACIONAL DE EDUCACION DIVERSIFICADA                        286
# INSTITUTO NACIONAL DE EDUCACIÓN DIVERSIFICADA                        102
# CENTRO DE EDUCACIÓN EXTRAESCOLAR -CEEX-                               32
# INSTITUTO DE EDUCACION DIVERSIFICADA POR COOPERATIVA DE ENSEÑANZA     22
# INSTITUTO DE EDUCACIÓN DIVERSIFICADA POR COOPERATIVA DE ENSEÑANZA     20
# Name: count, dtype: int64
#
# Columna: DIRECCION
# DIRECCION
# CABECERA MUNICIPAL    199
# BARRIO EL CENTRO       50
# BARRIO EL CALVARIO     14
# ALDEA PLAYITAS         12
# ALDEA CAMOJALLITO      11
# Name: count, dtype: int64
#
# Columna: TELEFONO
# TELEFONO
# NaN         46
# 22093200    12
# 77746400    10
# 24637777     9
# 23750057     9
# Name: count, dtype: int64
#
# Columna: SUPERVISOR
# SUPERVISOR
# MIGUEL ANGEL ARMAS ROCHA            190
# CARLOS HUMBERTO GONZÁLEZ DE LEÓN    160
# JUAN ENRIQUE MARTINEZ SOLANO        103
# REMY ARTURO SINAY GUDIEL             94
# ELSA YADIRA MARTINEZ PEREZ           84
# Name: count, dtype: int64
#
# Columna: DIRECTOR
# DIRECTOR
# NaN                                 26
# MARÍA DOLORES PÉREZ TUCHÁN          10
# HÉCTOR REYNALDO GÓMEZ AGUILAR        9
# SILVIA MARLENI ALVARADO GUARDADO     8
# SONIA JOSEFINA MORALES CAXAJ         8
# Name: count, dtype: int64
#
# Columna: NIVEL
# NIVEL
# DIVERSIFICADO    6600
# Name: count, dtype: int64
#
# Columna: SECTOR
# SECTOR
# PRIVADO        5418
# OFICIAL         874
# COOPERATIVA     213
# MUNICIPAL        95
# Name: count, dtype: int64
#
# Columna: AREA
# AREA
# URBANA             5250
# RURAL              1349
# SIN ESPECIFICAR       1
# Name: count, dtype: int64
#
# Columna: STATUS
# STATUS
# ABIERTA    6600
# Name: count, dtype: int64
#
# Columna: MODALIDAD
# MODALIDAD
# MONOLINGUE    6391
# BILINGUE       209
# Name: count, dtype: int64
#
# Columna: JORNADA
# JORNADA
# DOBLE          1957
# VESPERTINA     1836
# MATUTINA       1687
# SIN JORNADA    1001
# NOCTURNA        106
# Name: count, dtype: int64
#
# Columna: PLAN
# PLAN
# DIARIO(REGULAR)                        4052
# FIN DE SEMANA                          1310
# SEMIPRESENCIAL (FIN DE SEMANA)          490
# SEMIPRESENCIAL (UN DÍA A LA SEMANA)     409
# A DISTANCIA                             116
# Name: count, dtype: int64
#
# Columna: DEPARTAMENTAL
# DEPARTAMENTAL
# GUATEMALA OCCIDENTE    551
# GUATEMALA NORTE        545
# GUATEMALA SUR          528
# SAN MARCOS             432
# ESCUINTLA              393
# Name: count, dtype: int64
#
# 25
# CODIGO              0
# DISTRITO            0
# DEPARTAMENTO        0
# MUNICIPIO           0
# ESTABLECIMIENTO     0
# DIRECCION           2
# TELEFONO           46
# SUPERVISOR          0
# DIRECTOR           26
# NIVEL               0
# SECTOR              0
# AREA                0
# STATUS              0
# MODALIDAD           0
# JORNADA             0
# PLAN                0
# DEPARTAMENTAL       0
# dtype: int64

# %% [markdown]
# Ahora se revisan los valores únicos por columna. Se observa que hay varios de Ciudad Capital y de Guatemala. Tendremos qeu unirlos.

# %%
# Vista previa de los datos
print(df_unido.sample(10))
# Out:
# 25           CODIGO DISTRITO    DEPARTAMENTO                  MUNICIPIO  \
# 2759  17-04-0099-46   17-002           PETEN                 SAN ANDRES
# 6276  02-06-0022-46   02-020     EL PROGRESO                    SANSARE
# 6070  13-27-0076-46   13-048   HUEHUETENANGO                  AGUACATAN
# 2964  11-01-0078-46   11-016      RETALHULEU                 RETALHULEU
# 5505  05-02-0074-46   05-007       ESCUINTLA  SANTA LUCIA COTZUMALGUAPA
# 5496  05-02-0023-46   05-007       ESCUINTLA  SANTA LUCIA COTZUMALGUAPA
# 3797              MAURO AROLDO FIGUEROA ZAMORA  DIVERSIFICADO    PRIVADO
# 1417              AURA ELICIA CARTAGENA MONROY  DIVERSIFICADO    PRIVADO
#
# 25      AREA   STATUS   MODALIDAD      JORNADA  \
# 2759   RURAL  ABIERTA  MONOLINGUE        DOBLE
# 6276  URBANA  ABIERTA  MONOLINGUE        DOBLE
# 6070  URBANA  ABIERTA  MONOLINGUE   VESPERTINA
# 2964  URBANA  ABIERTA  MONOLINGUE     NOCTURNA
# 5505  URBANA  ABIERTA  MONOLINGUE   VESPERTINA
# 5496   RURAL  ABIERTA  MONOLINGUE   VESPERTINA
# 3835   RURAL  ABIERTA    BILINGUE   VESPERTINA
# 5648  URBANA  ABIERTA  MONOLINGUE        DOBLE
# 3797  URBANA  ABIERTA  MONOLINGUE        DOBLE
# 1417  URBANA  ABIERTA  MONOLINGUE  SIN JORNADA
#
# 25                              PLAN    DEPARTAMENTAL
# 2759                   FIN DE SEMANA            PETÉN
# 6276                   FIN DE SEMANA      EL PROGRESO
# 6070                 DIARIO(REGULAR)    HUEHUETENANGO
# 2964                 DIARIO(REGULAR)       RETALHULEU
# 5505                 DIARIO(REGULAR)        ESCUINTLA
# 5496                 DIARIO(REGULAR)        ESCUINTLA
# 3835                 DIARIO(REGULAR)    CHIMALTENANGO
# 5648                   FIN DE SEMANA        ESCUINTLA
# 3797                   FIN DE SEMANA    CHIMALTENANGO
# 1417  SEMIPRESENCIAL (FIN DE SEMANA)  GUATEMALA NORTE

# %% [markdown]
# Aquí se ve una vista previa del archivo todo unido.

# %% [markdown]
# # 3. Operaciones de limpieza

# %% [markdown]
# ### A. Unir los datos horizontalmente
#
# Se unen los 23 dataframes para obtener un solo archivo y limpiarlo más efectivamente.

# %%
todos = pd.concat(datos, ignore_index=True)
todos

# Verificación de que las filas son la cantidad correcta
contador = 0
for archivo in datos:
    contador = contador + len(archivo)

print(f'La cantidad de filas coincide: {len(todos) == contador}')
print(f'Hay {len(todos)} establecimientos educativos en Guatemala.')

# Cambiar encabezado a minúsculas
# Out:
# La cantidad de filas coincide: True
# Hay 6600 establecimientos educativos en Guatemala.

# %% [markdown]
# #### Renombramiento de columnas (mayúsculas a minúsculas)

# %%
df_unido.columns = df_unido.columns.str.strip().str.lower().str.replace(' ', '_')

# %% [markdown]
# ### B. Limpiar variable Teléfono
#
# 1. Se eliminan todos los espacios vacíos de la columna (" ") y caracteres no numéricos.
# 2. Se mantienen solo los primeros 8 caracteres y se pasan todos al mismo formato.
# 3. No se eliminan los registros nulos, sino solo se pone el valor NA.

# %%
def clean_phone(phone):
    phone = str(phone)
    phone = re.sub(r'\D', '', phone)  # elimina cualquier carácter no numérico
    if len(phone) == 8:
        return f' {phone[:4]}-{phone[4:]}'
    elif len(phone) == 0:
        return None
    else:
        return phone  # conservar si no es estándar

df_unido['telefono'] = df_unido['telefono'].apply(clean_phone)

df_unido['telefono'].head(10)
# Out:
# 0     7755-1548
# 1     7755-1551
# 2     7755-3814
# 3     7755-0476
# 4     7755-4695
# 5     7755-4630
# 6     7765-6620
# 7     7756-3692
# 8     7755-1705
# 9     7756-3633
# Name: telefono, dtype: object

# %% [markdown]
# ### C. Limpiar variables con nombres (director, supervisor) y dirección

# %% [markdown]
# #### Eliminación de espacios duplicados y caracteres invisibles

# %%
text_cols = ['departamento', 'municipio', 'establecimiento', 'direccion', 'supervisor', 'director', 'nivel', 'sector', 'area', 'status', 'modalidad', 'jornada', 'plan', 'departamental']

for col in text_cols:
    df_unido[col] = df_unido[col].astype(str).str.strip()
    df_unido[col] = df_unido[col].str.replace(r'\s+', ' ', regex=True)

# %% [markdown]
# #### Corrección de caracteres especiales (tildes y ñ)

# %% [markdown]
# Aquí se utilizan reemplazos usuales que se ven cuando se abren los documentos con tildes u otros caracteres complicados.

# %%
import unicodedata

def normalizar_texto(texto):
    if pd.isna(texto):
        return texto
    texto = str(texto)

    reemplazos = {
        "Ã¡": "á", "Ã©": "é", "Ã­": "í", "Ã³": "ó", "Ãº": "ú",
        "Ã": "Á", "Ã‰": "É", "Ã": "Í", "Ã“": "Ó", "Ãš": "Ú",
        "Ã±": "ñ", "Ã‘": "Ñ"
    }
    for k, v in reemplazos.items():
        texto = texto.replace(k, v)

    return texto

# %% [markdown]
# #### Correción de departamento “CIUDAD CAPITAL” a “GUATEMALA”

# %%
df_unido['departamento'] = df_unido['departamento'].replace(
    {'CIUDAD CAPITAL': 'GUATEMALA'}
)

# %% [markdown]
# #### Pasar texto de mayúsculas a formato de nombres propios

# %%
def to_title_case(texto):
    if pd.isna(texto):
        return texto
    return str(texto).lower().title()

cols_title_case = ['departamento', 'municipio', 'establecimiento', 'direccion', 'supervisor', 'director', 'nivel', 'sector', 'area', 'status', 'modalidad', 'jornada', 'plan', 'departamental']

for col in cols_title_case:
    if col in df_unido.columns:
        # Primero normalizar caracteres
        df_unido[col] = df_unido[col].apply(normalizar_texto)
        # Luego aplicar formato Título
        df_unido[col] = df_unido[col].apply(to_title_case)

# %% [markdown]
# #### Revisión y eliminación de valores faltantes en columnas clave

# %%
columnas_clave = ['departamento', 'municipio', 'establecimiento', 'direccion', 'supervisor', 'director', 'nivel', 'sector', 'area', 'status', 'modalidad', 'jornada', 'plan', 'departamental']
df_unido = df_unido.dropna(subset=columnas_clave)

# %% [markdown]
# #### Revisar que no haya duplicados con variaciones

# %% [markdown]
# Si se encuentran duplicados que podrían ser el mismo usando la librería fuzzy. Con esto, se encuentran nombres muy similares y se verifica si estos registros comparten número de teléfono. Si es así, el nombre del establecimiento se reemplaza por uno de los nombres para que todos los que sean iguales tengan el mismo.

# %%
from thefuzz import fuzz, process

col_establecimiento = "establecimiento"
col_telefono = "telefono"

df_rev = df_unido.copy()
posibles_duplicados = []
nombres_unicos = df_rev[col_establecimiento].dropna().unique()

for nombre in nombres_unicos:
    coincidencias = process.extract(nombre, nombres_unicos, scorer=fuzz.token_sort_ratio, limit=None)
    similares = [t[0] for t in coincidencias if t[1] >= 90 and t[0] != nombre]  # umbral 90%
    if similares:
        posibles_duplicados.append((nombre, similares))

# Mostrar posibles duplicados por nombre
for base, sims in posibles_duplicados:
    print(f"REVISAR: '{base}' -- {sims}")


#Reemplazos
reemplazos_contador = 0
reemplazos_ejemplos = []

for base, sims in posibles_duplicados:

    phones_base = set(df_rev.loc[df_rev[col_establecimiento] == base, col_telefono].dropna().unique())
    if not phones_base:
        # si la "base" no tiene teléfonos asociados, no hay nada que comparar
        continue

    for similar in sims:
        # teléfonos asociados con la variante "similar"
        phones_similar = set(df_rev.loc[df_rev[col_establecimiento] == similar, col_telefono].dropna().unique())
        # teléfonos que comparten exactamente (intersección)
        shared_phones = phones_base & phones_similar

        for phone in shared_phones:
            mask = (df_rev[col_establecimiento] == similar) & (df_rev[col_telefono] == phone)
            n_replace = mask.sum()
            if n_replace > 0:
                # Reemplazar el nombre variante por la versión base en las filas con el mismo teléfono
                df_rev.loc[mask, col_establecimiento] = base
                reemplazos_contador += int(n_replace)
                reemplazos_ejemplos.append({
                    "telefono": phone,
                    "de": similar,
                    "a": base,
                    "n_reemplazadas": int(n_replace)
                })

# Resumen
print(f"\nReemplazos realizados: {reemplazos_contador}")
if reemplazos_ejemplos:
    print("Ejemplos de reemplazo (hasta 10):")
    for ex in reemplazos_ejemplos[:10]:
        print(ex)
else:
    print("No se detectaron casos en los que la variante y la base compartieran teléfono.")
# Out:
# REVISAR: 'Colegio Mixto Bilingue Intercultural "Q´Ij"' -- ['Colegio Mixto Bilingue Intercultural Q Ij']
# REVISAR: 'Instituto Nacional De Educacion Diversificada' -- ['Instituto Nacional De Educación Diversificada', 'Instituto Nacional De Educaciòn Diversificada', 'Instituto Nacional De Educacion Diversificado', 'Instituto Nacional De Educación Diversificado', 'Instituto Nacional De Educacion Diversificada -Ined-', 'Instituto Nacional De Educacion Diversificada Ined', 'Instituto Nacional De Educacion Diversificada- Ined-', 'Instituto Nacional De Educacion Diversificada, Ined', 'Ined Instituto Nacional De Educación Diversificada', 'Instituto Nacional De Educación Diversificada -Ined-', 'Instituto Nacional De Educación Diversificada- Ined-', 'Instituto Nacional De Educación Diversificada, Ined', 'Instituto Nacional De Educacion Diversificada Puente', 'Instituto Nacional De Educacion Diversificada "Itzapa"', 'Instituto Nacional De Educacion Diversificado-Ined-', 'Instituto Municipal De Educacion Diversificada', 'Instituto Nacional De Educacion Diversificada Patulul', 'Instituto Nacional De Educacion Diversificada "Poaquil"', 'Instituto Nacional De Educacion Básica Y Diversificada', 'Instituto Nacional De Educacion Diversificada Morazan', 'Instituto Nacional De Educación Diversificada "Pachalí"', 'Instituto Nacional De Educación Diversificada Petatán', 'Instituto Municipal De Educación Diversificada', 'Instituto Nacional De Educacion Diversificada Chicacao', 'Instituto Nacional De Educacion Diversificada Zunilito', 'Instituto Nacional De Educacion Basica Y Diversificada', 'Instituto Nacional De Educacion Diversificada Oro Verde', 'Instituto Nacional De Educación Diversificada "La Ceiba"', 'Instituto Nacional De Educación Diversificada Carranza']
# REVISAR: 'Liceo Mixto Quiche' -- ['Liceo Mixto Quiché']
# REVISAR: 'Instituto Privado Mixto Ciencia Y Cultura' -- ['Instituto Privado Mixto "Ciencia Y Cultura"']
# REVISAR: 'Colegio Mixto Bilingue Intercultural Q Ij' -- ['Colegio Mixto Bilingue Intercultural "Q´Ij"']
# REVISAR: 'Escuela Normal Bilingüe Intercultural K´ Iche´ Tijob´ Äl Utüx Mayab´ Winäq Oxlajuj Tz´ I´' -- ['Escuela Normal Bilingue Intercultural K´Iche´ Tijob´Al Utux Mayab´ Winaq Oxlajuj Tz´ I´']
programa Nacional De Educacion Alternativa, Pronea', 'Programa Nacional De Educacion Alternativa-Pronea-', 'Programa Nacional De Educación Alternativa, Pronea.', 'Programa Nacional De Educación Alternativa, -Pronea-.', 'Programa Nacional De Educación Alternativa -Pronea-', 'Programa Nacional De Educación Alternativa Pronea', 'Programa Nacional De Educación Alternativa, Pronea', 'Programa Nacional De Educación Alternativa , Pronea', 'Programa Naciona De Educación Alternativa -Pronea-', 'Programa De Educacion Alternativa Pronea']
# REVISAR: 'Programa De Modalidades Flexibles Para La Educacion Media' -- ['Programa Modalidades Flexibles Para La Educación Media']
# REVISAR: 'Colegio Privado Mixto "Nuestra Señora Del Carmen"' -- ['Colegio Privado Mixto Nuestra Señora Del Carmen']
# REVISAR: 'Instituto Nacional De Educación Básica Y Diversificado Nuevo Amanecer Con Visión' -- ['Instituto Nacional De Educacion Basica Y Diversificado Nuevo Amanecer Con Vision']
# REVISAR: 'Instituto De Computación Informática' -- ['Instituto De Computacion Informatica']
# REVISAR: 'Instituto Privado Mixto Central De Suchitepequez' -- ['Instituto Privado Mixto "Central De Suchitepéquez"']
# REVISAR: 'Instituto Tecnico Privado Jose Ortega Y Gasset' -- ['Instituto Tecnico Privado "Jose Ortega Y Gasset"']
# REVISAR: 'Colegio Centro De Estudios Integrales Cei' -- ['Colegio Centro De Estudios Integrales']
# REVISAR: 'Instituto Nacional De Educacion Diversificada Cuyotenango' -- ['Instituto Nacional De Educacion Diversificada "Acatenango"']
# REVISAR: 'Colegio Privado Mixto Liceo Cuyoteco' -- ["Colegio Privado Mixto 'Liceo Cuyoteco'"]
# REVISAR: 'Colegio Privado Mixto 'Liceo Cuyoteco'' -- ['Colegio Privado Mixto Liceo Cuyoteco']
# REVISAR: 'Colegio "Monte Verde"' -- ['Colegio Monte Verde']
# REVISAR: 'Liceo San Jose' -- ['Liceo "San Jose"', 'Liceo San José', 'Liceo "San José"']
# REVISAR: 'Instituto Nacional De Educacion Diversificada Santo Domingo' -- ['Instituto Nacional De Educación Diversificada "Santo Domingo"']
# REVISAR: 'Colegio Privado Mixto "Tecnologico"' -- ['Colegio Privado Mixto Tecnológico Rural']
# REVISAR: 'Colegio Privado Mixto "Liceo Lorenzano"' -- ['Colegio Privado Mixto Liceo Lorenzano']
# REVISAR: 'Colegio Privado Mixto Liceo Lorenzano' -- ['Colegio Privado Mixto "Liceo Lorenzano"']
# REVISAR: 'Instituto Privado Mixto "Concepcion"' -- ['Instituto Privado Mixto "Concepción"']
# REVISAR: 'Instituto Privado Mixto "Concepción"' -- ['Instituto Privado Mixto "Concepcion"']
# REVISAR: 'Colegio Privado Mixto "Americano"' -- ['Colegio Privado Mixto Americano']
# REVISAR: 'Colegio Privado Mixto Liceo San Antonio' -- ['Colegio Privado Liceo San Antonio']
# REVISAR: 'Liceo De Computacion Siglo 21' -- ['Liceo De Computación "Siglo 21"', "Liceo De Computacion 'Siglo 21' No.3", 'Liceo De Computacion Siglo 21 No.3', 'Liceo De Computación Siglo 21 No. 3']
# REVISAR: 'Colegio Evangelico "Nueva Jerusalen"' -- ['Colegio Evangelico Nueva Jerusalen']
# REVISAR: 'Colegio Evangelico Nueva Jerusalen' -- ['Colegio Evangelico "Nueva Jerusalen"']
# REVISAR: 'Liceo De Computación "Siglo 21"' -- ['Liceo De Computacion Siglo 21', 'Liceo De Computación Siglo 21 No. 3', "Liceo De Computacion 'Siglo 21' No.3", 'Liceo De Computacion Siglo 21 No.3']
# REVISAR: 'Institiuto Privado Mixto Por Madurez El Saber' -- ['Instituto Privado Mixto Por Madurez El Saber']
# REVISAR: 'Colegio Privado Mixto Americano' -- ['Colegio Privado Mixto "Americano"']
# REVISAR: 'Instituto Privado Mixto Profesional La Educacion' -- ['Instituto Privado Mixto Profesional Educación Ipef']
# REVISAR: 'Instituto Privado Mixto Por Madurez El Saber' -- ['Institiuto Privado Mixto Por Madurez El Saber']
# REVISAR: 'Colegio Privado Mixto Innovacion Educativa' -- ['Colegio Privado Mixto "Innovacion Educativa"']
# REVISAR: 'Colegio Privado Mixto "Innovacion Educativa"' -- ['Colegio Privado Mixto Innovacion Educativa']
# REVISAR: 'Instituto Nacional De Educacion Diversificada Chicacao' -- ['Instituto Nacional De Educacion Básica Y Diversificada', 'Instituto Nacional De Educacion Diversificada', 'Instituto Nacional De Educacion Diversificada "Acatenango"', 'Instituto Nacional De Educacion Basica Y Diversificada', 'Instituto Nacional De Educación Diversificada', 'Instituto Nacional De Educaciòn Diversificada', 'Instituto Nacional De Educación Diversificada "La Ceiba"', 'Instituto Nacional De Educación Diversificada Carranza']
# REVISAR: 'Colegio Privado Mixto Pamaxán' -- ['Colegio Privado Mixto Pamaxan']
# REVISAR: 'Colegio Privado Mixto Pamaxan' -- ['Colegio Privado Mixto Pamaxán']
# REVISAR: 'Instituto Nacional De Educacion Diversificada Patulul' -- ['Instituto Nacional De Educacion Diversificada "Poaquil"', 'Instituto Nacional De Educación Diversificada "Pachalí"', 'Instituto Nacional De Educación Diversificada Petatán', 'Instituto Nacional De Educacion Diversificada', 'Instituto Nacional De Educacion Diversificada Puente', 'Instituto Nacional De Educación Diversificada', 'Instituto Nacional De Educaciòn Diversificada', 'Instituto Nacional De Educacion Diversificado', 'Instituto Nacional De Educacion Diversificada Zunilito']
# REVISAR: 'Instituto Privado Mixto De Computacion Informatica Ici' -- ['Instituto Privado Mixto De Computacion Informatica', 'Instituto Privado Mixto De Computación Informática "I.C.I."', 'Instituto Privado Mixto De Computación Informática']
# REVISAR: 'Colegio Privado "San Andres"' -- ['Colegio Privado Mixto San Andres']
# REVISAR: 'Colegio Cristiano Emmanuel' -- ['Colegio Cristiano Emmanuel.', 'Colegio Cristiano "Emanuel"', 'Colegio Cristiano Emanuel.']
# REVISAR: 'Colegio Privado Mixto "Santa Barbara"' -- ['Colegio Privado Mixto Santa Barbara']
# REVISAR: 'Colegio Privado Mixto Santa Barbara' -- ['Colegio Privado Mixto "Santa Barbara"']
# REVISAR: 'Instituto Municipal De Educacion Media Imem' -- ['Instituto Municipal De Educacion Media', 'Instituto Municipal De Educación Media']
# REVISAR: 'Instituto Privado Mixto Evangelico "Los Olivos"' -- ['Instituto Privado Mixto Evangelico Los Olivos']
# REVISAR: 'Instituto Normal Privado Mixto "Jorge Rabbi Matul Garcia"' -- ['Instituto Privado Mixto Jorge Rabbi Matul Garcia']
# REVISAR: 'Colegio Privado Mixto Elim' -- ['Colegio Privado Mixto "Elohim"', 'Colegio Privado Mixto "Elhohim"', 'Colegio Privado Mixto "Jedima"']
# REVISAR: 'Instituto Privado Mixto Evangelico Los Olivos' -- ['Instituto Privado Mixto Evangelico "Los Olivos"']
# REVISAR: 'Colegio Privado Mixto La "Union"' -- ['Colegio Privado Mixto "La Union"']
# REVISAR: 'Colegio Privado Mixto "La Union"' -- ['Colegio Privado Mixto La "Union"']
# REVISAR: 'Instituto Privado Mixto "Prof. Jorge Rabbi Matul Garcia"' -- ['Instituto Privado Mixto Jorge Rabbi Matul Garcia']
# REVISAR: 'Instituto Privado Mixto Jorge Rabbi Matul Garcia' -- ['Instituto Privado Mixto "Prof. Jorge Rabbi Matul Garcia"', 'Instituto Normal Privado Mixto "Jorge Rabbi Matul Garcia"']
# REVISAR: 'Instituto Nacional De Educacion Diversificada
# REVISAR: 'Colegio Particular Mixto "Sagrado Corazón"' -- ['Colegio Particular Mixto Sagrado Corazón', 'Colegio Particular Mixto Sagrado Corazon']
# REVISAR: 'Colegio Mixto Evangelico Casa De Jehová' -- ['Colegio Mixto Evangélico Casa De Jehová']
# REVISAR: 'Colegio De 'Estudios Tecnicos Especializados En Computacion' (Cetesc)' -- ['Colegio De Estudios Tecnicos Especializados En Computacion Cetesc']
# REVISAR: 'Instituto Tecnológico Privado Urbano Mixto "Ferdinand Lassalle"' -- ['Instituto Tecnologico Privado Urbano Mixto Ferdinand Lassalle']
# REVISAR: 'Colegio Particular "Liceo Minerva"' -- ['Colegio Particular Mixto "Liceo Minerva"']
# REVISAR: 'Centro De Educación Extraescolar Ceiba' -- ['Centro De Educación Extraescolar -Ceex-', '"Centro De Educación Extraescolar-Ceex"', 'Centro De Educación Extraescolar Ceex', 'Centro De Educación Extraescolar - Ceex', 'Centro De Educación Extraescolar Grupo Ceiba', 'Centro De Educacion Extraescolar -Ceex-', 'Centro De Edcación Extraescolar-Ceex-', 'Centro De Educación Extraescolar']
# ...
# REVISAR: 'Escuela En Ciencias De La Comunicación "Ecco Ii"' -- ['Escuela En Ciencias De La Comunicación -Ecco-', 'Escuela En Ciencias De La Comunicacion Ecco']
# REVISAR: 'Colegio Particular Mixto Génesis' -- ['Colegio Particular Mixto "Genesis"', 'Colegio Particular Mixto Genesis']
# REVISAR: 'Colegio Particular Mixto Genesis' -- ['Colegio Particular Mixto "Genesis"', 'Colegio Particular Mixto Génesis']
# REVISAR: 'Colegio "San Francisco"' -- ['Colegio San Francisco']
# REVISAR: 'Colegio Particular Mixto "Eben Ezer"' -- ['Colegio Particular Mixto Eben Ezer']
# REVISAR: 'Colegio Tecnico Profesional "San Cristobal"' -- ['Colegio Tecnico Profesional San Cristobal']
# REVISAR: 'Instituto Nacional De Educación Diversificada Ined "2 De Junio"' -- ['Ined Instituto Nacional De Educación Diversificada', 'Instituto Nacional De Educación Diversificada -Ined-', 'Instituto Nacional De Educación Diversificada- Ined-', 'Instituto Nacional De Educación Diversificada, Ined']
# REVISAR: 'Centro De Integración De Técnicas Educativas -Cite-' -- ['Centro De Integracion De Tecnicas Educativas Cite']
# REVISAR: 'Liceo Bethel' -- ['"Liceo Bethel"']
# REVISAR: 'Colegio Particular Integral "Evolución"' -- ['Colegio Particular Mixto Integral "Evolucion"']
# REVISAR: 'Instituto Técnico Particular De Diversificado Intecpadi' -- ['Instituto Técnico Particular De Diversificado -Intecpadi-', 'Instituto Tecnico Particular De Diversificado -Intecpadi-', 'Instituto Tecnico Particular De Diversificado, Intecpadi', 'Instituto Tecnico Particular De Diversificado Intecpadi']
# REVISAR: 'Escuela En Ciencias De La Comunicación -Ecco-' -- ['Escuela En Ciencias De La Comunicacion Ecco', 'Escuela En Ciencias De La Comunicación "Ecco Ii"']
# REVISAR: 'Instituto Tecnológico De Computación De Oriente' -- ['Instituto Tecnologico De Computacion De Oriente', 'Instituto Tecnologico De Computacion De Oriente Itco', 'Instituto Tecnológico De Computación Intecom']
# REVISAR: '"Liceo Bethel"' -- ['Liceo Bethel']
# REVISAR: 'Colegio Mixto Bilingüe "Santa Fe"' -- ['Colegio Mixto Bilingüe Santa Fe']
# REVISAR: 'Instituto Tecnologico De Computacion De Oriente' -- ['Instituto Tecnológico De Computación De Oriente', 'Instituto Tecnologico De Computacion De Oriente Itco']
# REVISAR: 'Escuela En Ciencias De La Comunicacion Ecco' -- ['Escuela En Ciencias De La Comunicación -Ecco-', 'Escuela En Ciencias De La Comunicación "Ecco Ii"']
# REVISAR: 'Instituto Tecnico Particular De Diversificado, Intecpadi' -- ['Instituto Tecnico Particular De Diversificado -Intecpadi-', 'Instituto Tecnico Particular De Diversificado Intecpadi', 'Instituto Técnico Particular De Diversificado -Intecpadi-', 'Instituto Técnico Particular De Diversificado Intecpadi']
# REVISAR: 'Instituto Tecnico Particular De Diversificado Intecpadi' -- ['Instituto Tecnico Particular De Diversificado -Intecpadi-', 'Instituto Tecnico Particular De Diversificado, Intecpadi', 'Instituto Técnico Particular De Diversificado -Intecpadi-', 'Instituto Técnico Particular De Diversificado Intecpadi']
# REVISAR: 'Colegio Particular Mixto Eben Ezer' -- ['Colegio Particular Mixto "Eben Ezer"']
# REVISAR: 'Colegio Particular Mixto "Liceo Progreso"' -- ['Colegio Particular Mixto Liceo Progreso']
# REVISAR: 'Colegio Particular Mixto Liceo Progreso' -- ['Colegio Particular Mixto "Liceo Progreso"']
# REVISAR: 'Instituto Tecnico Industrial Henry Ford' -- ['Instituto Tecnico Industrial "Henry Ford"', "Instituto Tecnico Industrial 'Henry Ford'", 'Instituto Técnico Industrial "Henry Ford"', 'Instituto Técnico Industrial Henry Ford']
# REVISAR: 'Colegio Particular Mixto Evangélico "Shalom"' -- ['Colegio Particular Mixto Evangélico "Samaria"', 'Colegio Particular Mixto Evangelico "Samaria"']
# REVISAR: 'Instituto Tecnico Industrial 'Henry Ford'' -- ['Instituto Tecnico Industrial "Henry Ford"', 'Instituto Tecnico Industrial Henry Ford', 'Instituto Técnico Industrial "Henry Ford"', 'Instituto Técnico Industrial Henry Ford']
# REVISAR: 'Liceo Juan Pablo Ii' -- ['Liceo "San Juan Pablo Ii"']
# REVISAR: 'Liceo "San Juan Pablo Ii"' -- ['Liceo Juan Pablo Ii']
# REVISAR: 'Instituto Particular Mixto "María Chinchilla"' -- ['Instituto Particular Mixto "Maria Chinchilla"', 'Instituto Particular Mixto Maria Chinchilla']
# REVISAR: 'Centro Educativo De Informática' -- ['Centro Educativo De Informatica', 'Centro Educativo De Informática Sinaí', 'Centro Educativo De Informatica Sinai']
# REVISAR: 'Instituto Técnico Industrial Henry Ford' -- ['Instituto Técnico Industrial "Henry Ford"', 'Instituto Tecnico Industrial "Henry Ford"', 'Instituto Tecnico Industrial Henry Ford', "Instituto Tecnico Industrial 'Henry Ford'"]
# REVISAR: 'Instituto Particular Mixto "Maria Chinchilla"' -- ['Instituto Particular Mixto Maria Chinchilla', 'Instituto Particular Mixto "María Chinchilla"']
# REVISAR: 'Instituto Particular Mixto Maria Chinchilla' -- ['Instituto Particular Mixto "Maria Chinchilla"', 'Instituto Particular Mixto "María Chinchilla"']
# REVISAR: 'Centro Educativo De Informatica' -- ['Centro Educativo De Informática', 'Centro Educativo De Informatica Sinai', 'Centro Educativo De Informática Sinaí']
# REVISAR: 'Instituto Particular Mixto El Jícaro' -- ['Instituto Particular Mixto El Jicaro']
# REVISAR: 'Colegio Particular Mixto "San Francisco"' -- ['Colegio Particular Mixto San Francisco', 'Colegio Particular Mixto "San Francisco De Asís"']
# REVISAR: 'Instituto Particular Mixto El Jicaro' -- ['Instituto Particular Mixto El Jícaro']
# REVISAR: 'Colegio Particular Mixto De Diversificado "Liceo San Cristobal"' -- ['Colegio Particular Mixto De Diversificado Liceo San Cristobal']
# REVISAR: 'Colegio Privado "San Francisco De Asis"' -- ['Colegio Privado "San Francisco De Asís"']
# REVISAR: 'Colegio Particular Mixto "San Cristóbal"' -- ['Colegio Particular Mixto San Cristobal']
# REVISAR: 'Colegio Particular Mixto De Diversificado Liceo San Cristobal' -- ['Colegio Particular Mixto De Diversificado "Liceo San Cristobal"']
# REVISAR: 'Colegio Particular Mixto San Cristobal' -- ['Colegio Particular Mixto "San Cristóbal"']
# REVISAR: 'Instituto Municipal De Diversificado' -- ['Instituto Diversificado Municipal']
# REVISAR: 'Colegio Integral "Ciencia Y Desarrollo"' -- ['Colegio Integral Ciencia Y Desarrollo', 'Colegio Integral Ciencia Y Desarrollo Ii']
# REVISAR: 'Colegio Integral Ciencia Y Desarrollo' -- ['Colegio Integral "Ciencia Y Desarrollo"', 'Colegio Integral Ciencia Y Desarrollo Ii']
# REVISAR: 'Instituto De Diversificado Por Cooperativa -Indicopa-' -- ['Instituto Por Cooperativa De Diversificado', 'Instituto De Diversificado Por Cooperativa', 'Instituto Diversificado De Educación Por Cooperativa']
# REVISAR: 'Colegio Mixto Bilingüe Santa Fe' -- ['Colegio Mixto Bilingüe "Santa Fe"']
# REVISAR: 'Colegio Particular Mixto "Liceo Estanzuela"' -- ['Colegio Particular Mixto Liceo Estanzuela']
# REVISAR: 'Colegio Particular Mixto Nuestra Señora De Concepcion' -- ['Colegio Particular Mixto "Nuestra Señora De Concepción"', 'Colegio Privado Mixto Nuestra Señora De Concepcion', 'Colegio Privado Mixto Nuestra Señora De Concepción']
# REVISAR: 'Colegio Particular Mixto Liceo Estanzuela' -- ['Colegio Particular Mixto "Liceo Estanzuela"']
# REVISAR: 'Instituto Particular Mixto De Formación Y Desarrollo Profesional Indeforp' -- ['Instituto Particular Mixto De Formación Y Desarrollo Profesional "Indeforp"', 'Instituto Particular Mixto De Formacion Y Desarrollo Profesional Indeforp', 'Instituto Particular De Formación Y Desarrollo Profesional "Indeforp"', 'Instituto Particular Formación Y Desarrollo Profesional "Indeforp Ii"', 'Instituto Particular Formacion Y Desarrollo Profesional "Indeforp Ii"']
# REVISAR: 'Instituto Particular Mixto De Formacion Y Desarrollo Profesional Indeforp' -- ['Instituto Particular Mixto De Formación Y Desarrollo Profesional Indeforp', 'Instituto Particular Mixto De Formación Y Desarrollo Profesional "Indeforp"', 'Instituto Particular De Formación Y Desarrollo Profesional "Indeforp"', 'Instituto Particular Formacion Y Desarrollo Profesional "Indeforp Ii"', 'Instituto Particular Formación Y Desarrollo Profesional "Indeforp Ii"']
# REVISAR: 'Instituto Particular Formacion Y Desarrollo Profesional "Indeforp Ii"' -- ['Instituto Particular Formación Y Desarrollo Profesional "Indeforp Ii"', 'Instituto Particular De Formación Y Desarrollo Profesional "Indeforp"', 'Instituto Particular Mixto De Formacion Y Desarrollo Profesional Indeforp', 'Instituto Particular Mixto De Formación Y Desarrollo Profesional Indeforp', 'Instituto Particular Mixto De Formación Y Desarrollo Profesional "Indeforp"']
# REVISAR: 'Instituto Particular Mixto De Formación Y Desarrollo Profesional "Indeforp"' -- ['Instituto Particular Mixto De Formación Y Desarrollo Profesional Indeforp', 'Instituto Particular Mixto De Formacion Y Desarrollo Profesional Indeforp', 'Instituto Particular De Formación Y Desarrollo Profesional "Indeforp"', 'Instituto Particular Formación Y Desarrollo Profesional "Indeforp Ii"', 'Instituto Particular Formacion Y Desarrollo Profesional "Indeforp Ii"']
# REVISAR: 'Colegio Particular Mixto "Nuestra Señora De Concepción"' -- ['Colegio Particular Mixto Nuestra Señora De Concepcion', 'Colegio Privado Mixto Nuestra Señora De Concepción', 'Colegio Privado Mixto Nuestra Señora De Concepcion']
# REVISAR: 'Colegio Particular Mixto San Francisco' -- ['Colegio Particular Mixto "San Francisco"', 'Colegio Particular Mixto "San Francisco De Asís"']
# REVISAR: 'Instituto Particular De Formación Y Desarrollo Profesional "Indeforp"' -- ['Instituto Particular Mixto De Formación Y Desarrollo Profesional Indeforp', 'Instituto Particular Mixto De Formación Y Desarrollo Profesional "Indeforp"', 'Instituto Particular Formación Y Desarrollo Profesional "Indeforp Ii"', 'Instituto Particular Mixto De Formacion Y Desarrollo Profesional Indeforp', 'Instituto Particular Formacion Y Desarrollo Profesional "Indeforp Ii"']
# REVISAR: 'Instituto Particular Formación Y Desarrollo Profesional "Indeforp Ii"' -- ['Instituto Particular Formacion Y Desarrollo Profesional "Indeforp Ii"', 'Instituto Particular De Formación Y Desarrollo Profesional "Indeforp"', 'Instituto Particular Mixto De Formación Y Desarrollo Profesional Indeforp', 'Instituto Particular Mixto De Formación Y Desarrollo Profesional "Indeforp"', 'Instituto Particular Mixto De Formacion Y Desarrollo Profesional Indeforp']
# REVISAR: 'Colegio Bilingüe Nueva Era' -- ['Colegio Bilingue Nueva Era', 'Colegio Bilingue "Nueva Era Ii"']
# REVISAR: 'Colegio Particular Mixto Evangélico "Samaria"' -- ['Colegio Particular Mixto Evangelico "Samaria"', 'Colegio Particular Mixto Evangélico "Shalom"']
# REVISAR: 'Colegio Particular Mixto "San José Obrero Ii"' -- ['Colegio Particular Mixto "San Jose Obrero Ii"', 'Colegio Particular Mixto San Jose Obrero Ii', 'Colegio Particular Mixto San José Obrero I', 'Colegio Particular Mixto San Jose Obrero I']
# REVISAR: 'Colegio Particular Mixto Evangelico "Samaria"' -- ['Colegio Particular Mixto Evangélico "Samaria"', 'Colegio Particular Mixto Evangélico "Shalom"']
# REVISAR: 'Colegio Particular Mixto "San Jose Obrero Ii"' -- ['Colegio Particular Mixto San Jose Obrero Ii', 'Colegio Particular Mixto "San José Obrero Ii"', 'Colegio Particular Mixto San Jose Obrero I', 'Colegio Particular Mixto San José Obrero I']
# REVISAR: 'Colegio Bilingue Nueva Era' -- ['Colegio Bilingüe Nueva Era', 'Colegio Bilingue "Nueva Era Ii"']
# REVISAR: 'Colegio Bilingue "Nueva Era Ii"' -- ['Colegio Bilingue Nueva Era', 'Colegio Bilingüe Nueva Era']
# REVISAR: 'Colegio Particular Mixto San José Obrero I' -- ['Colegio Particular Mixto "San José Obrero Ii"', 'Colegio Particular Mixto San Jose Obrero I', 'Colegio Particular Mixto "San Jose Obrero Ii"', 'Colegio Particular Mixto San Jose Obrero Ii']
# REVISAR: 'Colegio Particular Mixto "Nuevo Amanecer"' -- ['Colegio Particular Mixto Nuevo Amanecer']
# REVISAR: 'Colegio Particular Mixto San Jose Obrero I' -- ['Colegio Particular Mixto "San Jose Obrero Ii"', 'Colegio Particular Mixto San Jose Obrero Ii', 'Colegio Particular Mixto San José Obrero I', 'Colegio Particular Mixto "San José Obrero Ii"']
# REVISAR: 'Colegio Particular Mixto San Jose Obrero Ii' -- ['Colegio Particular Mixto "San Jose Obrero Ii"', 'Colegio Particular Mixto "San José Obrero Ii"', 'Colegio Particular Mixto San Jose Obrero I', 'Colegio Particular Mixto San José Obrero I']
# REVISAR: 'Instituto Mixto De Educacion "Conguaquense"' -- ['Instituto Mixto De Educacion Conguaquense', 'Instituto Mixto De Educación Conguaquense']
# REVISAR: 'Instituto Mixto De Educacion Conguaquense' -- ['Instituto Mixto De Educacion "Conguaquense"', 'Instituto Mixto De Educación Conguaquense']
# REVISAR: 'Instituto Mixto De Educación Conguaquense' -- ['Instituto Mixto De Educacion "Conguaquense"', 'Instituto Mixto De Educacion Conguaquense']
# REVISAR: 'Instituto Tecnologico De Suroriente' -- ['Instituto Tecnológico De Suroriente']
# REVISAR: 'Instituto Tecnológico De Suroriente' -- ['Instituto Tecnologico De Suroriente']
# REVISAR: 'Colegio Integral Ciencia Y Desarrollo Ii' -- ['Colegio Integral "Ciencia Y Desarrollo"', 'Colegio Integral Ciencia Y Desarrollo']
# REVISAR: 'Colegio Particular Mixto La Bendicion' -- ['Colegio Particular Mixto Bendicion']
# REVISAR: 'Colegio Particular Mixto Bendicion' -- ['Colegio Particular Mixto La Bendicion']
# REVISAR: 'Instituto Pedagógico De Educación Media San José "Ipemsa"' -- ['Instituto Pedagogico De Educación Media San Jose "Ipemsa"']
# REVISAR: 'Instituto Pedagogico De Educación Media San Jose "Ipemsa"' -- ['Instituto Pedagógico De Educación Media San José "Ipemsa"']
# REVISAR: 'Colegio Particular Mixto Bilingue Santa Fe' -- ['Colegio Particular Mixto Bilingüe Santa Fe', 'Colegio Particular Mixto Bilingue "Santa Familia"']
# REVISAR: 'Colegio Particular Mixto Bilingüe "San Pedro Apóstol"' -- ['Colegio Particular Mixto Bilingue "San Pedro Apóstol"']
# REVISAR: 'Colegio Particular Mixto Bilingue "San Pedro Apóstol"' -- ['Colegio Particular Mixto Bilingüe "San Pedro Apóstol"']
# REVISAR: 'Colegio Integral De Computación "Educare"' -- ['Colegio Integral De Computacion Educare']
# REVISAR: 'Colegio Particular Mixto Bilingüe Santa Fe' -- ['Colegio Particular Mixto Bilingue Santa Fe', 'Colegio Particular Mixto Bilingue "Santa Familia"']
# REVISAR: 'Colegio Integral De Computacion Educare' -- ['Colegio Integral De Computación "Educare"']
#
# Reemplazos realizados: 671
# Ejemplos de reemplazo (hasta 10):
# {'telefono': ' 7755-0476', 'de': 'Colegio Mixto Bilingue Intercultural Q Ij', 'a': 'Colegio Mixto Bilingue Intercultural "Q´Ij"', 'n_reemplazadas': 3}
# {'telefono': ' 3019-4721', 'de': 'Instituto Nacional De Educación Diversificada', 'a': 'Instituto Nacional De Educacion Diversificada', 'n_reemplazadas': 1}
# {'telefono': ' 3044-1503', 'de': 'Instituto Nacional De Educación Diversificada', 'a': 'Instituto Nacional De Educacion Diversificada', 'n_reemplazadas': 1}
# {'telefono': ' 4492-7951', 'de': 'Instituto Nacional De Educación Diversificada', 'a': 'Instituto Nacional De Educacion Diversificada', 'n_reemplazadas': 1}
# {'telefono': ' 4012-4127', 'de': 'Instituto Nacional De Educación Diversificada', 'a': 'Instituto Nacional De Educacion Diversificada', 'n_reemplazadas': 1}
# {'telefono': ' 5694-7315', 'de': 'Instituto Nacional De Educación Diversificada', 'a': 'Instituto Nacional De Educacion Diversificada', 'n_reemplazadas': 1}
# {'telefono': ' 3946-4750', 'de': 'Instituto Nacional De Educacion Básica Y Diversificada', 'a': 'Instituto Nacional De Educacion Diversificada', 'n_reemplazadas': 1}
# {'telefono': ' 7755-1705', 'de': 'Liceo Mixto Quiché', 'a': 'Liceo Mixto Quiche', 'n_reemplazadas': 1}
# {'telefono': ' 7756-3487', 'de': 'Instituto Privado Mixto "Ciencia Y Cultura"', 'a': 'Instituto Privado Mixto Ciencia Y Cultura', 'n_reemplazadas': 1}
# {'telefono': ' 7756-3721', 'de': 'Escuela Normal Bilingue Intercultural K´Iche´ Tijob´Al Utux Mayab´ Winaq Oxlajuj Tz´ I´', 'a': 'Escuela Normal Bilingüe Intercultural K´ Iche´ Tijob´ Äl Utüx Mayab´ Winäq Oxlajuj Tz´ I´', 'n_reemplazadas': 1}

# %% [markdown]
# # 4. Guardar datos limpios

# %%
df_rev.to_csv("dataset_limpio.csv", index=False, encoding='utf-8-sig')
print("Dataset limpio exportado como dataset_limpio.csv")
# Out:
# Dataset limpio exportado como dataset_limpio.csv
